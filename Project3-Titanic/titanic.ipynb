# %% [markdown]
# # IMPORT THE LIBRARIES

# %%
import pandas as pd

# %% [markdown]
# # LOADING THE DATASET

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %% [markdown]
# # UNDERSTANDING THE DATA

# %%
df.columns  # all the column names , google it and get to know the meaning of each and every column
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
df.head() # top 5 values
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
df.tail() # display last 5 values
# Out:
#       pclass                       name     sex   age  sibsp  parch  ticket  \
# 1304       3       Zabour, Miss. Hileni  female  14.5      1      0    2665
# 1305       3      Zabour, Miss. Thamine  female   NaN      1      0    2665
# 1306       3  Zakarian, Mr. Mapriededer    male  26.5      0      0    2656
# 1307       3        Zakarian, Mr. Ortin    male  27.0      0      0    2670
# 1308       3         Zimmerman, Mr. Leo    male  29.0      0      0  315082
#
#          fare cabin embarked  survived
# 1304  14.4542   NaN        C         0
# 1305  14.4542   NaN        C         0
# 1306   7.2250   NaN        C         0
# 1307   7.2250   NaN        C         0
# 1308   7.8750   NaN        S         0

# %%
df.info()
#OBSERVATION
#handle the missing values
#handle invalid dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# 1. Remove duplicates
# 2. Mean , Median , Mode
# 3. astype()/to_datetime()

# %%
df.duplicated().any()
#  NO DUPLICATES
# Out:
# np.False_

# %% [markdown]
# MISSING DATA COLUMNS
# > age - float - mean
# > fare - float - mean
# > cabin(too many null values so we drop this column)
# > embarked - object - mode

# %%
#Finding the replacement values for null values
a_m=df['age'].mean() #OR directly df['age']=df['age'].fillna(df['age'].mean)
f_m=df['fare'].mean()
e_m=df['embarked'].mode()[0] #return type of mode is Series

# %%
df['age']=df['age'].fillna(a_m)
df['fare']=df['fare'].fillna(f_m)
df['embarked']=df['embarked'].fillna(e_m)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1309 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
#Drop Cabin Column as more than 50% of data is missing
df=df.drop(columns=['cabin'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   embarked  1309 non-null   object
#  9   survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare embarked  survived
# ...

# %% [markdown]
# #Checking the dtype and handling the wrong ones
# #NO INVALID DTYPES

# %% [markdown]
# # DATA TRANSFORMATION or FEATURE ENGINEERING

# %%
df['age']=df['age'].round(1)  # if there is more decimal values are there to reduce that we use round() 
df['fare']=df['fare'].round(1)  # example-- 2.345464 ---> 2.3
df['age']
# df['fare']
# Out:
# 0       29.0
# 1        0.9
# 2        2.0
# 3       30.0
# 4       25.0
#         ...
# 1304    14.5
# 1305    29.9
# 1306    26.5
# 1307    27.0
# 1308    29.0
# Name: age, Length: 1309, dtype: float64

# %%
df['family_cnt']=df['sibsp']+df['parch']  # --> horizontal adding to store in familycount varible
# df  #sibling count + prentchhild

# it is column there in table it will rewrite the column if not it will [create the new column] it will go to the last position

#Now no need of sibsp and parch column so we should drop them
df=df.drop(columns=['sibsp','parch']) # df= why/ COZ WE ARE REMOVING PERMANTALY
# df

# %%
df['embarked'].unique() #to check the unique values
#S:Southampton,C:CHerbourg,Q:Queenstown (replacing short-form to full-form)

# now we need to replace this by S C Q to there names

df['embarked']=df['embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'})
df
# Out:
#       pclass                                             name     sex   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  female  29.0
# 1          1                   Allison, Master. Hudson Trevor    male   0.9
# 2          1                     Allison, Miss. Helen Loraine  female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  female  14.5
# 1305       3                            Zabour, Miss. Thamine  female  29.9
# 1306       3                        Zakarian, Mr. Mapriededer    male  26.5
# 1307       3                              Zakarian, Mr. Ortin    male  27.0
# 1308       3                               Zimmerman, Mr. Leo    male  29.0
#
#       ticket   fare     embarked  survived  family_cnt
# ...

# %%
#we are changing or renaming sex column name to gender
df=df.rename(columns={'sex':'gender'})  #in rename we have to functions it is renaming index so we need to sepcify columns=
df                                       # using , we can change multiple columns ass well

#TITLE CASE CHARACTER
df['gender']=df['gender'].str.title()
df
# Out:
#       pclass                                             name  gender   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  Female  29.0
# 1          1                   Allison, Master. Hudson Trevor    Male   0.9
# 2          1                     Allison, Miss. Helen Loraine  Female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    Male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  Female  14.5
# 1305       3                            Zabour, Miss. Thamine  Female  29.9
# 1306       3                        Zakarian, Mr. Mapriededer    Male  26.5
# 1307       3                              Zakarian, Mr. Ortin    Male  27.0
# 1308       3                               Zimmerman, Mr. Leo    Male  29.0
#
#       ticket   fare     embarked  survived  family_cnt
# ...

# %%
#SPLITING THE COLUMNS
df['l_name']=df['name'].str.split(',',expand=True)[0]

temp=df['name'].str.split(',',expand=True)[1]
df[['title','f_name']]=temp.str.split('.',n=1,expand=True)

# df['l_name']=df['name'].str.split(',',expand=True)[0]  #add the last name to the column separtately

# temp=df['l_name']=df['name'].str.split(',',expand=True)[1]
# df[ ['title','f_name'] ]=temp.str.split('.',n=1,expand=True)  #to control the dots we use n = 1.

# %%
df
# Out:
#       pclass                                             name  gender   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  Female  29.0
# 1          1                   Allison, Master. Hudson Trevor    Male   0.9
# 2          1                     Allison, Miss. Helen Loraine  Female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    Male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  Female  14.5
# 1305       3                            Zabour, Miss. Thamine  Female  29.9
# 1306       3                        Zakarian, Mr. Mapriededer    Male  26.5
# 1307       3                              Zakarian, Mr. Ortin    Male  27.0
# 1308       3                               Zimmerman, Mr. Leo    Male  29.0
#
# ...

# %%
df=df.drop(columns=['name'])
df
# Out:
#       pclass  gender   age  ticket   fare     embarked  survived  family_cnt  \
# 0          1  Female  29.0   24160  211.3  Southampton         1           0
# 1          1    Male   0.9  113781  151.6  Southampton         1           3
# 2          1  Female   2.0  113781  151.6  Southampton         0           3
# 3          1    Male  30.0  113781  151.6  Southampton         0           3
# 4          1  Female  25.0  113781  151.6  Southampton         0           3
# ...      ...     ...   ...     ...    ...          ...       ...         ...
# 1304       3  Female  14.5    2665   14.5    Cherbourg         0           1
# 1305       3  Female  29.9    2665   14.5    Cherbourg         0           1
# 1306       3    Male  26.5    2656    7.2    Cherbourg         0           0
# 1307       3    Male  27.0    2670    7.2    Cherbourg         0           0
# 1308       3    Male  29.0  315082    7.9  Southampton         0           0
#
# ...

# %%
# APPLY METHOD : single looping (if nested loop is present we cannot use apply we should use looping statements)
# axis=0 : all the rows of 1st column , all the rows of 2nd column....
# axis=1 : all the columns of 1st row , all the columns of 2nd row....

# axis=0 : COLUMN BY COLUMN
# axis=1 : ROW BY ROW

# APPLY -- it is a combination of looping concept [if it is single loop]
# axis=0 [columnwise addition - vertical] colbycol
# axis=1 [recordwise addition - horizontal] rowbyrow

# def fun():
#     return d.sum()

# df.apply(fun,axis=0)

# %%
#Create a new column called Companion type which will have family , solo -> USING APPLY METHOD
#APPLY METHOD >1. first create a function >2. in the apply ,method use that function

# This method is incorrect since people with family_cnt=0 are not always solo travellers they maybe travelling with friends or business purpose
# So we must also consider the ticket category and check according to both family_count and ticket_category
# Let us take the tickets with value 1 and family_cnt = 0 and compare to get exact evaluation


# def fun(d):
#     if d['family_cnt']>0:
#         return 'family'
#     else:
#         return 'solo'
# companiontype = df.apply(fun,axis=1)


# g=df['ticket'].value_counts()
# solo_ticket=g[g==1].index

# def fun(d):
#         if d['family_cnt']>0 :
#             return 'family'
#         else:
#             if d['ticket'] in (solo_ticket):   #g==1: 
#                  return 'solo'
#             else:
#                  return 'friends'
# #isin method is applied for complete method , in method is used in strings , apply works like for ,it check for each value separately so use in operator
            
# df['companion_type']=df.apply(fun,axis=1)

# %%
# Displaying column names or shuffuling it
lst=['ticket','title','f_name','l_name','gender','age','family_cnt','pclass','embarked','fare','survived'] # we can arragne the columns like this
df=df[lst]
df
# Out:
#       ticket    title                              f_name     l_name  gender  \
# 0      24160     Miss                    Elisabeth Walton      Allen  Female
# 1     113781   Master                       Hudson Trevor    Allison    Male
# 2     113781     Miss                       Helen Loraine    Allison  Female
# 3     113781       Mr             Hudson Joshua Creighton    Allison    Male
# 4     113781      Mrs   Hudson J C (Bessie Waldo Daniels)    Allison  Female
# ...      ...      ...                                 ...        ...     ...
# 1304    2665     Miss                              Hileni     Zabour  Female
# 1305    2665     Miss                             Thamine     Zabour  Female
# 1306    2656       Mr                         Mapriededer   Zakarian    Male
# 1307    2670       Mr                               Ortin   Zakarian    Male
# 1308  315082       Mr                                 Leo  Zimmerman    Male
#
# ...

# %%
df=df.sort_values(by='ticket',ascending=True)   #only 1 word here ascending=True(low to high),  ascending=False--> Descending(high to low)

# %%
#the index number are jumbeled so we are Resetting it by using "reset_index"
df=df.reset_index(drop=True)     #drop=True  --> deletes the old index and adds the new index values 
df
# Out:
#            ticket          title                                      f_name  \
# 0          110152           Miss                                      Gladys
# 1          110152   the Countess          of (Lucy Noel Martha Dyer-Edwards)
# 2          110152           Miss                                     Roberta
# 3          110413           Miss                                        Ruth
# 4          110413            Mrs                    Emil (Tillie Mandelbaum)
# ...           ...            ...                                         ...
# 1304  W.E.P. 5734            Mrs   Herbert Fuller (Carrie Constance Toogood)
# 1305  W.E.P. 5734             Mr                              Herbert Fuller
# 1306    W/C 14208             Mr                                      Walter
# 1307    WE/P 5735           Capt                              Edward Gifford
# 1308    WE/P 5735           Miss                                   Harriet R
#
# ...

# %%
#Cut --> for bins take the min and max values and create a range 
df.agg({'age':['min','max']})
# Out:
#       age
# min   0.2
# max  80.0

# %%
df['age category']=pd.cut(df['age'],bins=[0,3,15,25,60,81],labels=['baby','child','teen','adult','senior']) #last bin value take max+1 to include it

# %%
df
# Out:
#            ticket          title                                      f_name  \
# 0          110152           Miss                                      Gladys
# 1          110152   the Countess          of (Lucy Noel Martha Dyer-Edwards)
# 2          110152           Miss                                     Roberta
# 3          110413           Miss                                        Ruth
# 4          110413            Mrs                    Emil (Tillie Mandelbaum)
# ...           ...            ...                                         ...
# 1304  W.E.P. 5734            Mrs   Herbert Fuller (Carrie Constance Toogood)
# 1305  W.E.P. 5734             Mr                              Herbert Fuller
# 1306    W/C 14208             Mr                                      Walter
# 1307    WE/P 5735           Capt                              Edward Gifford
# 1308    WE/P 5735           Miss                                   Harriet R
#
# ...

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# # (1) Get all the passenger details

# %%
df
# Out:
#            ticket          title                                      f_name  \
# 0          110152           Miss                                      Gladys
# 1          110152   the Countess          of (Lucy Noel Martha Dyer-Edwards)
# 2          110152           Miss                                     Roberta
# 3          110413           Miss                                        Ruth
# 4          110413            Mrs                    Emil (Tillie Mandelbaum)
# ...           ...            ...                                         ...
# 1304  W.E.P. 5734            Mrs   Herbert Fuller (Carrie Constance Toogood)
# 1305  W.E.P. 5734             Mr                              Herbert Fuller
# 1306    W/C 14208             Mr                                      Walter
# 1307    WE/P 5735           Capt                              Edward Gifford
# 1308    WE/P 5735           Miss                                   Harriet R
#
# ...

# %% [markdown]
# # (2) Get all the passengers name(Full name)

# %%
df['f_name']+' '+df['l_name']
#full name = first name + last name seperated by space
# Out:
# 0                                           Gladys Cherry
# 1               of (Lucy Noel Martha Dyer-Edwards) Rothes
# 2                                          Roberta Maioni
# 3                                            Ruth Taussig
# 4                        Emil (Tillie Mandelbaum) Taussig
#                               ...
# 1304     Herbert Fuller (Carrie Constance Toogood) Cha...
# 1305                               Herbert Fuller Chaffee
# 1306                                        Walter Harris
# 1307                                Edward Gifford Crosby
# 1308                                     Harriet R Crosby
# Length: 1309, dtype: object

# %% [markdown]
# # (3) Get all the passengers name , gender , age

# %%
# df[['f_name','gender','age']]

#OR -- using list we can do

lst=['f_name','gender','age']
df[lst]
# Out:
#                                           f_name  gender   age
# 0                                         Gladys  Female  30.0
# 1             of (Lucy Noel Martha Dyer-Edwards)  Female  33.0
# 2                                        Roberta  Female  16.0
# 3                                           Ruth  Female  18.0
# 4                       Emil (Tillie Mandelbaum)  Female  39.0
# ...                                          ...     ...   ...
# 1304   Herbert Fuller (Carrie Constance Toogood)  Female  47.0
# 1305                              Herbert Fuller    Male  46.0
# 1306                                      Walter    Male  30.0
# 1307                              Edward Gifford    Male  70.0
# 1308                                   Harriet R  Female  36.0
#
# [1309 rows x 3 columns]

# %% [markdown]
# # (4) Get Male passenger details

# %%
#whenever we have condition we can use loc or query , without using loc and query we cannot perform the conditions

#query returns the rows where we pasas column name in " " and value using ' '

# df.query("gender=='Male'")
#OR
df.loc[df['gender']=='Male']
# Out:
#            ticket  title               f_name    l_name gender   age  \
# 5          110413     Mr                 Emil   Taussig   Male  52.0
# 6          110465     Mr   Walter Chamberlain    Porter   Male  47.0
# 7          110465     Mr        George Quincy  Clifford   Male  29.9
# 8          110469     Mr          John Edward   Maguire   Male  30.0
# 9          110489     Mr           John James  Borebank   Male  42.0
# ...           ...    ...                  ...       ...    ...   ...
# 1298   W./C. 6608     Mr         William Neal      Ford   Male  16.0
# 1302   W./C. 6608     Mr        Edward Watson      Ford   Male  18.0
# 1305  W.E.P. 5734     Mr       Herbert Fuller   Chaffee   Male  46.0
# 1306    W/C 14208     Mr               Walter    Harris   Male  30.0
# 1307    WE/P 5735   Capt       Edward Gifford    Crosby   Male  70.0
#
#       family_cnt  pclass     embarked  fare  survived age category
# 5              2       1  Southampton  79.6         0        adult
# ...

# %% [markdown]
# # (5)Get Female passenger name and passenger class

# %%
# df.query("gender=='Female'")[['f_name','pclass']]
df.loc[df['gender']=='Female',['f_name','pclass']]
# Out:
#                                           f_name  pclass
# 0                                         Gladys       1
# 1             of (Lucy Noel Martha Dyer-Edwards)       1
# 2                                        Roberta       1
# 3                                           Ruth       1
# 4                       Emil (Tillie Mandelbaum)       1
# ...                                          ...     ...
# 1300                    Doolina Margaret "Daisy"       3
# 1301                        Robina Maggie "Ruby"       3
# 1303                                Alice Phoebe       3
# 1304   Herbert Fuller (Carrie Constance Toogood)       1
# 1308                                   Harriet R       1
#
# [466 rows x 2 columns]

# %% [markdown]
# # (6) Get Male passenger details who are travelling with pclass 1

# %%
# df.query("gender='Male' and pclass==1")
# In query for multiple conditions use and within the same " " and for vlaues ' ' don't consider it different 

df.loc[(df['gender']=='Male') & (df['pclass']==1)]
#while passing multiple conditions in loc use '&' operator and pass each condition with () for clarity
# Out:
#            ticket  title               f_name      l_name gender   age  \
# 5          110413     Mr                 Emil     Taussig   Male  52.0
# 6          110465     Mr   Walter Chamberlain      Porter   Male  47.0
# 7          110465     Mr        George Quincy    Clifford   Male  29.9
# 8          110469     Mr          John Edward     Maguire   Male  30.0
# 9          110489     Mr           John James    Borebank   Male  42.0
# ...           ...    ...                  ...         ...    ...   ...
# 1180     PC 17759     Mr      William Bertram  Greenfield   Male  23.0
# 1184     PC 17760     Mr                Sante    Ringhini   Male  22.0
# 1185     PC 17761     Mr        Walter Donald     Douglas   Male  50.0
# 1305  W.E.P. 5734     Mr       Herbert Fuller     Chaffee   Male  46.0
# 1307    WE/P 5735   Capt       Edward Gifford      Crosby   Male  70.0
#
#       family_cnt  pclass     embarked   fare  survived age category
# ...

# %% [markdown]
# # (7) Get female passenegers details who are travelling with pclass 1 or 3

# %%
# df.query("gender=='Female' and pclass==1 or pclass==3")

# df.loc[(df['gender']=='Female') & (df['pclass']==1) | (df['pclass']==3)]
#OR
# df.loc[(df['gender']=='Female') & (df['pclass'].isin([1,3])),]

# %% [markdown]
# # (8) Get the number of passengers

# %%
df.shape[0]   #shape is a attribute which gives the count of rows 
df['ticket'].count()   # for count we cannot pass multiple columns
# Out:
# np.int64(1309)

# %% [markdown]
# # (9) Get the number of male passengers

# %%
# df.query("gender=='Male'").count() # this will give all the columns in which males are present so
# df.query("gender=='Male'")['gender'].count()

df.loc[df['gender']=='Male','gender'].count()
# Out:
# np.int64(843)

# %% [markdown]
# # (10)Get average fare amount of all passengers

# %%
df['fare'].mean().round(2)
# Out:
# np.float64(33.3)

# %% [markdown]
# # (11)Get total fare amount of survived passengers

# %%
df.query("survived==1")['fare'].sum()

df.loc[df['survived']==1,'fare'].sum()
# Out:
# np.float64(24681.9)

# %% [markdown]
# # (12) Get the highest and lowest age among the passengers

# %%
df['age'].max()
df['age'].min()

df.agg({'age':['max','min']})
# Out:
#       age
# max  80.0
# min   0.2

# %% [markdown]
# # (13) Get the total and highest fare along with the average age

# %%
df.agg({'fare':['max','min'],'age':'mean'})
# Out:
#        fare       age
# max   512.3       NaN
# min     0.0       NaN
# mean    NaN  29.88495

# %% [markdown]
# # (14) Gender wise no_of_passengers

# %%
# df['gender'].groupby()
df.groupby(['gender'])['gender'].count()   
# df.groupby(['gender']).agg({'gender':'count'})

# When we apply groupby it will always return grouped_object , on these grouped_objects we can perform Aggregation , Get_groups() and groups
# To get the result we have to apply aggregate function with groupby
# Out:
# gender
# Female    466
# Male      843
# Name: gender, dtype: int64

# %% [markdown]
# **The combination of Groupby() and Count() : value_counts()**

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      843
# Female    466
# Name: count, dtype: int64

# %% [markdown]
# # (15) Get the ticket-wise no_of_passengers

# %%
df['ticket'].value_counts()   #11 people are travelling with the ticket CA. 2343
# Out:
# ticket
# CA. 2343              11
# CA 2144                8
# 1601                   8
# PC 17608               7
# 347077                 7
#                       ..
# SOTON/O2 3101272       1
# SOTON/O2 3101284       1
# SOTON/O2 3101287       1
# SOTON/O.Q. 3101263     1
# SOTON/O.Q. 3101305     1
# Name: count, Length: 929, dtype: int64

# %% [markdown]
# After value_counts we get 2 columns , Index and values(count) , by default it will be in Descending order
#
# > The column used for grouping is treated as Index and
# > The column which is created using aggregate is treated as Values

# %%
#to get in ascending
df['ticket'].value_counts().sort_values()
# Out:
# ticket
# W./C. 6609       1
# A/5. 10482       1
# A/5. 13032       1
# A/5. 2151        1
# A/5 21172        1
#                 ..
# 3101295          7
# S.O.C. 14879     7
# 1601             8
# CA 2144          8
# CA. 2343        11
# Name: count, Length: 929, dtype: int64

# %% [markdown]
#  # (16) Get the passenger details only if their ticket is 1601

# %%
df.loc[df['ticket']=='1601']
# Out:
#     ticket title   f_name l_name gender   age  family_cnt  pclass  \
# 157   1601    Mr      Len    Lam   Male  29.9           0       3
# 158   1601    Mr      Lee   Bing   Male  32.0           0       3
# 159   1601    Mr    Chang   Chip   Male  32.0           0       3
# 160   1601    Mr     Ling    Hee   Male  29.9           0       3
# 161   1601    Mr   Choong    Foo   Male  29.9           0       3
# 162   1601    Mr      Ali    Lam   Male  29.9           0       3
# 163   1601    Mr      Lee   Ling   Male  28.0           0       3
# 164   1601    Mr     Fang   Lang   Male  26.0           0       3
#
#         embarked  fare  survived age category
# 157  Southampton  56.5         0        adult
# 158  Southampton  56.5         1        adult
# 159  Southampton  56.5         1        adult
# 160  Southampton  56.5         1        adult
# 161  Southampton  56.5         1        adult
# 162  Southampton  56.5         1        adult
# ...

# %% [markdown]
# # (17)Get the ticket value only if the count is 1  (OR)
# # Get the ticket where the occurrence is 1 (occurrence: no. of times it is present )

# %%
g=df['ticket'].value_counts()
g==1   # --> series of bool

g[g==1] #returns only True values 
#VERY IMP
g[g==1].values
g[g==1].index    #.index : will return a array having the index_elements , .values will return a array having the values_elements
# Out:
# Index(['111240', 'SOTON/OQ 3101316', 'SOTON/OQ 3101317', 'SOTON/OQ 392076',
#        'SOTON/OQ 392082', 'SOTON/OQ 392083', 'SOTON/OQ 392086',
#        'SOTON/OQ 392089', 'SOTON/OQ 392090', '113784',
#        ...
#        'SC/PARIS 2166', 'SC/PARIS 2168', 'SOTON/O.Q. 3101314',
#        'SOTON/O.Q. 392078', 'SOTON/O.Q. 392087', 'SOTON/O2 3101272',
#        'SOTON/O2 3101284', 'SOTON/O2 3101287', 'SOTON/O.Q. 3101263',
#        'SOTON/O.Q. 3101305'],
#       dtype='object', name='ticket', length=713)

# %% [markdown]
# Very IMP
# >If we want the True values then we should write the name again outside and take the condition within [ ]
#
# ex:
# a1=np.array([2,3,4])
# a1>2  --> returns [False,True,True]
# a1[a1>2] --> returns [3,4]

# %% [markdown]
# # (18) Get the Genderwise total_fare?

# %%
df.groupby(['gender'])['fare'].sum()
# Out:
# gender
# Female    21531.2
# Male      22055.5
# Name: fare, dtype: float64

# %% [markdown]
# # (19) Get the Gender with Highest fare --idxmax

# %%
df.groupby(['gender'])['fare'].sum().idxmax()
df.groupby(['gender'])['fare'].sum().idxmin()
# Out:
# 'Female'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fg = sns.FacetGrid(df,col='age category')

fg.map_dataframe(sns.barplot,x='survived',y='age category',hue='gender',palette='coolwarm',hue_order=['male','female'])

plt.legend()

# %%
# idx=df['pclass'].value_counts().index
idx=df['pclass'].value_counts().sort_values().index #ascending order

# %%
# this is without hue 
plt.figure(figsize=(4,2))
c=sns.countplot(x=df['pclass'],order=idx) # to change the order index is required
c.bar_label(c.containers[0])
plt.show()

# %%
#using hue
plt.figure(figsize=(4,2))
c=sns.countplot(x=df['pclass'],hue=df['gender'])

for i in c.containers:
    c.bar_label(i)
